# %%
import numpy as np
lines = []
with open("sun.txt") as f:
    for line in f:
        lines.append(line)

# %%
max_len = 0
for i in lines:
    if len(i)> max_len:
        max_len=len(i)

# %%
for i in lines:
    if len(i)==max_len:
        print i
# Out:
# /n/nuclear_power_plant/outdoor/sun_bswmqxwobwslxwwh.jpg
#
# /n/nuclear_power_plant/outdoor/sun_arjsectgfbjxkwjq.jpg
#
# /n/nuclear_power_plant/outdoor/sun_ayrfgqwfwypgqsun.jpg
#
# /n/nuclear_power_plant/outdoor/sun_bacnxjqfcwffnkqp.jpg
#
# /n/nuclear_power_plant/outdoor/sun_asmnotyszoxrjflt.jpg
#
# /n/nuclear_power_plant/outdoor/sun_ayuwiwfqrbkpwnbw.jpg
#
# /n/nuclear_power_plant/outdoor/sun_abixanxgsreeoifw.jpg
#
# /n/nuclear_power_plant/outdoor/sun_bnpnyuifkzxwucvh.jpg
#
# /n/nuclear_power_plant/outdoor/sun_bxgoyoyayrjvghpo.jpg
#
# /n/nuclear_power_plant/outdoor/sun_akqzqbabehvdrwsb.jpg
#
# /n/nuclear_power_plant/outdoor/sun_bckogefzdggvmzko.jpg
#
# /n/nuclear_power_plant/outdoor/sun_agukrhuverbxnrjw.jpg
#
# /n/nuclear_power_plant/outdoor/sun_arfenrxwuvdvfjlq.jpg
#
# /n/nuclear_power_plant/outdoor/sun_amkoljqsshyzfwki.jpg
#
# /n/nuclear_power_plant/outdoor/sun_azgsgidaxztuqkny.jpg
#
# /n/nuclear_power_plant/outdoor/sun_bcegfynepfajhzki.jpg
#
# ...
